# %%
from datetime import datetime
start_time = datetime.now()

# Load libraries
# %pip install keras
# %pip install tensorflow

import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline

print('LOAD DURATION:',datetime.now() - start_time) # about 3 minutes
# Out:
# LOAD DURATION: 0:00:01.671384

# %%
# %%time
property_data = pd.read_csv('Data/NY property data.csv')
NY_data_orig = property_data.copy()
# Out:
# CPU times: user 2.98 s, sys: 337 ms, total: 3.31 s
# Wall time: 3.32 s

# %%
property_data.shape
# Out:
# (1070994, 32)

# %%
property_data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                       10004                 10004
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR

# %%
numrecs = len(property_data)

# %% [markdown]
# ## Fill in missing ZIP

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 29890

# %%
for i in range(len(missing_zips)):
    if(property_data.loc[missing_zips[i]+1,'ZIP'] == property_data.loc[missing_zips[i]-1,'ZIP']):
        property_data.loc[missing_zips[i],'ZIP'] = property_data.loc[missing_zips[i]-1,'ZIP']

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 16437

# %%
for i in range(len(missing_zips)):
    property_data.loc[missing_zips[i],'ZIP'] = property_data.loc[missing_zips[i]-1,'ZIP']

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 0

# %% [markdown]
# ## Calculate means for AVTOT, AVLAND, FULLVAL by taxclass, avoiding the records with zeros

# %%
property_data['FULLVAL'].replace('NaN',0)
temp =property_data[property_data['FULLVAL']!=0]
mean_fullval = temp.groupby('TAXCLASS')['FULLVAL'].mean()
print(mean_fullval)
# Out:
# TAXCLASS
# 1     5.698435e+05
# 1A    3.352842e+05
# 1B    5.613639e+05
# 1C    7.615359e+05
# 1D    2.233614e+07
# 2     7.998018e+05
# 2A    8.640037e+05
# 2B    1.252989e+06
# 2C    7.728799e+05
# 3     1.112765e+05
# 4     3.211928e+06
# Name: FULLVAL, dtype: float64

# %%
property_data['AVLAND'].replace('NaN',0)
temp_avland = property_data[property_data['AVLAND']!=0]
mean_avland = temp_avland.groupby('TAXCLASS')['AVLAND'].mean()

# %%
property_data['AVTOT'].replace('NaN',0)
temp_avtot = property_data[property_data['AVTOT']!=0]
mean_avtot = temp_avtot.groupby('TAXCLASS')['AVTOT'].mean()

# %% [markdown]
# ## Substituting decent values for AVTOT, AVLAND, FULLVAL from averages by taxclass

# %%
# %%time
for index in mean_fullval.index:
    property_data.loc[(property_data['FULLVAL']==0)&(property_data['TAXCLASS']==index),'FULLVAL']=mean_fullval[index]
    property_data.loc[(property_data['AVLAND']==0)&(property_data['TAXCLASS']==index),'AVLAND']=mean_avland[index]
    property_data.loc[(property_data['AVTOT']==0)&(property_data['TAXCLASS']==index),'AVTOT']=mean_avtot[index]
# Out:
# CPU times: user 1.67 s, sys: 24.7 ms, total: 1.69 s
# Wall time: 1.69 s

# %%
property_data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                       10004                 10004
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR

# %% [markdown]
# ## STORIES

# %%
temp = property_data[property_data['STORIES'].isnull()]
len(temp)
# Out:
# 56264

# %%
temp['TAXCLASS'].value_counts()
# Out:
# 1B    24736
# 4     22354
# 3      4635
# 2      3435
# 1       897
# 2C      138
# 2B       34
# 2A       30
# 1A        5
# Name: TAXCLASS, dtype: int64

# %%
mean_stories = property_data.groupby('TAXCLASS')['STORIES'].mean()
print(mean_stories)
# Out:
# TAXCLASS
# 1      2.111641
# 1A     1.656837
# 1B     4.000000
# 1C     3.052748
# 1D     1.068966
# 2     16.095110
# 2A     2.844574
# 2B     4.004494
# 2C     4.745097
# 3      1.333333
# 4      5.446968
# Name: STORIES, dtype: float64

# %%
temp.head().transpose()
# Out:
#                              0                      1                     5   \
# RECORD                        1                      2                     6
# BBLE                 1000010101             1000010201            1000030002
# B                             1                      1                     1
# BLOCK                         1                      1                     3
# LOT                         101                    201                     2
# EASEMENT                    NaN                    NaN                   NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  PARKS AND RECREATION
# BLDGCL                       P7                     Z9                    Q1
# TAXCLASS                      4                      4                     4
# LTFRONT                     500                     27                   496
# LTDEPTH                    1046                      0                    76
# EXT                         NaN                    NaN                   NaN
# STORIES                     NaN                    NaN                   NaN
# FULLVAL                2.14e+07              1.938e+08              1.06e+07
# AVLAND               4.2255e+06              1.431e+07              4.77e+06
# AVTOT                  9.63e+06              8.721e+07              4.77e+06
# EXLAND               4.2255e+06              1.431e+07              4.77e+06
# EXTOT                  9.63e+06              8.721e+07              4.77e+06
# EXCD1                      4600                   4600                  2231
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND    PETER MINUIT PLAZA
# ZIP                       10004                  10004                 10004
# EXMPTCL                      X3                     X3                    X1
# BLDFRONT                      0                      0                     0
# BLDDEPTH                      0                      0                     0
# AVLAND2              3.7755e+06            1.11114e+07            4.2687e+06
# AVTOT2                8.613e+06            8.06904e+07            4.2687e+06
# EXLAND2              3.7755e+06            1.11114e+07            4.2687e+06
# EXTOT2                8.613e+06            8.06904e+07            4.2687e+06
# EXCD2                       NaN                    NaN                   NaN
# PERIOD                    FINAL                  FINAL                 FINAL
# YEAR                    2010/11                2010/11               2010/11
# VALTYPE                   AC-TR                  AC-TR                 AC-TR
#
#                               65                      66
# RECORD                        66                      67
# BBLE                  1000051004              1000051005
# B                              1                       1
# BLOCK                          5                       5
# LOT                         1004                    1005
# EASEMENT                     NaN                     NaN
# OWNER       SLG BROAD STREET 125   AMERICAN CIVIL LIBERT
# BLDGCL                        R5                      R5
# TAXCLASS                       4                       4
# LTFRONT                        0                       0
# LTDEPTH                        0                       0
# EXT                          NaN                     NaN
# STORIES                      NaN                     NaN
# FULLVAL               5.2668e+06              5.2668e+06
# AVLAND                    858211                  858211
# AVTOT                2.37006e+06             2.37006e+06
# EXLAND                    858211                  858211
# EXTOT                2.37006e+06             2.37006e+06
# EXCD1                       1501                    1501
# STADDR    2 AMERICAN EXPRESS PLZ  2 AMERICAN EXPRESS PLZ
# ZIP                        10004                   10004
# EXMPTCL                      NaN                     NaN
# BLDFRONT                       0                       0
# BLDDEPTH                       0                       0
# AVLAND2                   856725                  856725
# AVTOT2               2.02527e+06             2.02527e+06
# EXLAND2                   856725                  856725
# EXTOT2               2.02527e+06             2.02527e+06
# EXCD2                        NaN                     NaN
# PERIOD                     FINAL                   FINAL
# YEAR                     2010/11                 2010/11
# VALTYPE                    AC-TR                   AC-TR

# %%
len(property_data[property_data["STORIES"]==0])
# Out:
# 0

# %%
property_data['STORIES']=property_data['STORIES'].fillna(value =0)
for index in mean_stories.index:
    property_data.loc[(property_data['STORIES']==0)&(property_data['TAXCLASS']==index),'STORIES']=mean_stories[index]

# %%
property_data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                 5.44697                5.44697                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                       10004                 10004
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR

# %% [markdown]
# ## Fill in LTFRONT, LTDEPTH, BLDDEPTH, BLDFRONT with averages by TAXCLASS

# %%
# %%time
# as these 4 values do not have NAs, we just need to replace 0s. 
# calculate groupwise average. 1st replace 0 by NAs so they are not counted in calculating mean.
property_data.loc[property_data['LTFRONT']==0,'LTFRONT']=np.nan
property_data.loc[property_data['LTDEPTH']==0,'LTDEPTH']=np.nan
property_data.loc[property_data['BLDFRONT']==0,'BLDFRONT']=np.nan
property_data.loc[property_data['BLDDEPTH']==0,'BLDDEPTH']=np.nan
property_data.loc[property_data['LTFRONT']==1,'LTFRONT']=np.nan
property_data.loc[property_data['LTDEPTH']==1,'LTDEPTH']=np.nan
property_data.loc[property_data['BLDFRONT']==1,'BLDFRONT']=np.nan
property_data.loc[property_data['BLDDEPTH']==1,'BLDDEPTH']=np.nan

#calculate mean now (mean function ignores NAs but not 0s hence we converted 0 to NA)
mean_LTFRONT=property_data.groupby(property_data['TAXCLASS'])['LTFRONT'].mean()
mean_LTDEPTH=property_data.groupby(property_data['TAXCLASS'])['LTDEPTH'].mean()
mean_BLDFRONT=property_data.groupby(property_data['TAXCLASS'])['BLDFRONT'].mean()
mean_BLDDEPTH=property_data.groupby(property_data['TAXCLASS'])['BLDDEPTH'].mean()

#impute values
for index in mean_LTFRONT.index:
    property_data.loc[(property_data['LTFRONT'].isnull())&(property_data['TAXCLASS']==index),'LTFRONT']=mean_LTFRONT[index]    
    property_data.loc[(property_data['LTDEPTH'].isnull())&(property_data['TAXCLASS']==index),'LTDEPTH']=mean_LTDEPTH[index]
    property_data.loc[(property_data['BLDFRONT'].isnull())&(property_data['TAXCLASS']==index),'BLDFRONT']=mean_BLDFRONT[index]
    property_data.loc[(property_data['BLDDEPTH'].isnull())&(property_data['TAXCLASS']==index),'BLDDEPTH']=mean_BLDDEPTH[index]
# Out:
# CPU times: user 2.6 s, sys: 414 ms, total: 3.01 s
# Wall time: 3.01 s

# %%
mean_LTFRONT
# Out:
# TAXCLASS
# 1      30.939072
# 1A     51.124586
# 1B     54.610260
# 1C     27.250825
# 1D    338.275862
# 2     113.541391
# 2A     25.917860
# 2B     27.254835
# 2C     29.987290
# 3     136.107963
# 4      93.937119
# Name: LTFRONT, dtype: float64

# %%
mean_LTDEPTH
# Out:
# TAXCLASS
# 1      99.282535
# 1A     90.083551
# 1B    111.856649
# 1C     96.778878
# 1D    497.827586
# 2     132.606230
# 2A     97.282675
# 2B     95.751182
# 2C     95.737463
# 3     280.837313
# 4     133.871567
# Name: LTDEPTH, dtype: float64

# %%
mean_BLDFRONT
# Out:
# TAXCLASS
# 1     21.401447
# 1A    25.024532
# 1B    39.500000
# 1C    23.367589
# 1D    19.586207
# 2     92.203204
# 2A    22.983862
# 2B    26.042747
# 2C    27.888318
# 3     19.333333
# 4     64.439787
# Name: BLDFRONT, dtype: float64

# %%
mean_BLDDEPTH
# Out:
# TAXCLASS
# 1      41.556940
# 1A     44.949251
# 1B     82.666667
# 1C     60.094862
# 1D     36.862069
# 2     108.005699
# 2A     62.430662
# 2B     66.587020
# 2C     68.660429
# 3      33.750000
# 4      87.820730
# Name: BLDDEPTH, dtype: float64

# %%
data = property_data.copy()
data.shape
# Out:
# (1070994, 32)

# %%
data.dtypes
# Out:
# RECORD        int64
# BBLE         object
# B             int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT     float64
# LTDEPTH     float64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT    float64
# BLDDEPTH    float64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
# convert ZIP to an integer rather than a float
data['ZIP'] = data['ZIP'].astype(str)
data['zip3'] = data['ZIP'].str[:3]

# %%
data.count()
# Out:
# RECORD      1070994
# BBLE        1070994
# B           1070994
# BLOCK       1070994
# LOT         1070994
# EASEMENT       4636
# OWNER       1039249
# BLDGCL      1070994
# TAXCLASS    1070994
# LTFRONT     1070994
# LTDEPTH     1070994
# EXT          354305
# STORIES     1070994
# FULLVAL     1070994
# AVLAND      1070994
# AVTOT       1070994
# EXLAND      1070994
# EXTOT       1070994
# EXCD1        638488
# STADDR      1070318
# ZIP         1070994
# EXMPTCL       15579
# BLDFRONT    1070994
# BLDDEPTH    1070994
# AVLAND2      282726
# AVTOT2       282732
# EXLAND2       87449
# EXTOT2       130828
# EXCD2         92948
# PERIOD      1070994
# YEAR        1070994
# VALTYPE     1070994
# zip3        1070994
# dtype: int64

# %%
cols = data.columns
print(cols)
# Out:
# Index(['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3'],
#       dtype='object')

# %%
data['ltsize'] = data['LTFRONT'] * data['LTDEPTH']
data['bldsize'] = data['BLDFRONT'] * data['BLDDEPTH']
data['bldvol'] = data['bldsize'] * data['STORIES']

# %%
data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                133.872                    564
# EXT                         NaN                    NaN                      E
# STORIES                 5.44697                5.44697                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                     10004.0                10004.0                10004.0
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                64.4398                64.4398                    709
# BLDDEPTH                87.8207                87.8207                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
# zip3                        100                    100                    100
# ltsize                   523000                3614.53                 399876
# bldsize                 5659.15                5659.15                 399876
# bldvol                  30825.2                30825.2            1.19963e+06
#
#                               3                     4
# RECORD                        4                     5
# BBLE                 1000020023            1000030001
# B                             1                     1
# BLOCK                         2                     3
# LOT                          23                     1
# EASEMENT                    NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION
# BLDGCL                       T2                    Q1
# TAXCLASS                      4                     4
# LTFRONT                     793                   323
# LTDEPTH                     551                  1260
# EXT                         NaN                   NaN
# STORIES                       2                     1
# FULLVAL                3.92e+07             2.723e+08
# AVLAND               1.5255e+07            1.2105e+08
# AVTOT                 1.764e+07           1.22535e+08
# EXLAND               1.5255e+07            1.2105e+08
# EXTOT                 1.764e+07           1.22535e+08
# EXCD1                      2191                  2231
# STADDR                   PIER 6          BATTERY PARK
# ZIP                     10004.0               10004.0
# EXMPTCL                      X1                    X1
# BLDFRONT                     85                    89
# BLDDEPTH                    551                    57
# AVLAND2              1.3644e+07           1.06349e+08
# AVTOT2                1.575e+07           1.07758e+08
# EXLAND2              1.3644e+07           1.06349e+08
# EXTOT2                1.575e+07           1.07758e+08
# EXCD2                       NaN                   NaN
# PERIOD                    FINAL                 FINAL
# YEAR                    2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR
# zip3                        100                   100
# ltsize                   436943                406980
# bldsize                   46835                  5073
# bldvol                    93670                  5073

# %%
data['r1'] = data['FULLVAL'] / data['ltsize']
data['r2'] = data['FULLVAL'] / data['bldsize']
data['r3'] = data['FULLVAL'] / data['bldvol']
data['r4'] = data['AVLAND'] / data['ltsize']
data['r5'] = data['AVLAND'] / data['bldsize']
data['r6'] = data['AVLAND'] / data['bldvol']
data['r7'] = data['AVTOT'] / data['ltsize']
data['r8'] = data['AVTOT'] / data['bldsize']
data['r9'] = data['AVTOT'] / data['bldvol']

# %%
# %%time
ninevars = ['r1','r2','r3','r4','r5','r6','r7','r8','r9']
zip5_mean = data.groupby('ZIP')[ninevars].mean()
zip3_mean = data.groupby('zip3')[ninevars].mean()
taxclass_mean = data.groupby('TAXCLASS')[ninevars].mean()
borough_mean = data.groupby('B')[ninevars].mean()
data = data.join(zip5_mean, on='ZIP', rsuffix='_zip5')
data = data.join(zip3_mean, on='zip3', rsuffix='_zip3')
data = data.join(taxclass_mean, on='TAXCLASS', rsuffix='_taxclass')
data = data.join(borough_mean, on='B', rsuffix='_boro')
rsuffix = ['_zip5', '_zip3', '_taxclass', '_boro']
for var in ninevars:
    for r in rsuffix:
        data[str(var)+r] = data[var] / data[str(var)+r]
# Out:
# CPU times: user 2.29 s, sys: 489 ms, total: 2.78 s
# Wall time: 2.36 s

# %%
data.head().transpose()
# Out:
#                   0           1           2           3           4
# RECORD            1           2           3           4           5
# BBLE     1000010101  1000010201  1000020001  1000020023  1000030001
# B                 1           1           1           1           1
# BLOCK             1           1           2           2           3
# LOT             101         201           1          23           1
# ...             ...         ...         ...         ...         ...
# r5_boro     11.8983     40.2944     1.55451     5.19036     380.238
# r6_boro     6.28149     21.2728     1.49007     7.46281     1093.43
# r7_boro    0.199588     261.531     1.27698    0.437606      3.2636
# r8_boro      11.908      107.84    0.824401     2.63567     169.028
# r9_boro     9.36471     84.8075     1.17714      5.6451     724.051
#
# [81 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3', 'ltsize', 'bldsize',
#        'bldvol', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9',
#        'r1_zip5', 'r2_zip5', 'r3_zip5', 'r4_zip5', 'r5_zip5', 'r6_zip5',
#        'r7_zip5', 'r8_zip5', 'r9_zip5', 'r1_zip3', 'r2_zip3', 'r3_zip3',
#        'r4_zip3', 'r5_zip3', 'r6_zip3', 'r7_zip3', 'r8_zip3', 'r9_zip3',
#        'r1_taxclass', 'r2_taxclass', 'r3_taxclass', 'r4_taxclass',
#        'r5_taxclass', 'r6_taxclass', 'r7_taxclass', 'r8_taxclass',
#        'r9_taxclass', 'r1_boro', 'r2_boro', 'r3_boro', 'r4_boro', 'r5_boro',
#        'r6_boro', 'r7_boro', 'r8_boro', 'r9_boro'],
#       dtype='object')

# %%
dropcols = ['RECORD','BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT',
       'OWNER', 'BLDGCL', 'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES',
       'FULLVAL', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR',
       'ZIP', 'EXMPTCL', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2',
       'EXLAND2', 'EXTOT2', 'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3','ltsize','bldsize','bldvol']
data = data.drop(columns = dropcols)
data.shape
# Out:
# (1070994, 45)

# %%
data.head().transpose()
# Out:
#                        0             1           2           3             4
# r1             40.917782  53616.895011  261.796157   89.714219    669.074647
# r2           3781.487225  34245.431036  261.796157  836.980890  53676.325646
# r3            694.237107   6287.063144   87.265386  418.490445  53676.325646
# r4              8.079350   3959.018409   97.551991   34.913021    297.434763
# r5            746.667022   2528.648700   97.551991  325.717946  23861.620343
# r6            137.079388    464.230514   32.517330  162.858973  23861.620343
# r7             18.413002  24127.602755  117.808271   40.371399    301.083591
# r8           1701.669251  15410.443966  117.808271  376.641401  24154.346541
# r9            312.406698   2829.178415   39.269424  188.320700  24154.346541
# r1_zip5         0.100365    131.514300    0.642147    0.220056      1.641141
# r2_zip5         6.121586     55.437539    0.423804    1.354930     86.892859
# r3_zip5         4.513332     40.873075    0.567324    2.720665    348.957284
# r4_zip5         0.144135     70.628446    1.740317    0.622844      5.306203
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.170250e-02 -1.012244e-01 -4.391781e-02 -3.271184e-02 -3.514611e-01
# 25%   -1.900615e-02 -8.214703e-02 -3.091588e-02 -2.339241e-02 -2.029755e-01
# 50%   -1.070379e-02 -6.965849e-02 -2.306247e-02 -1.485576e-02 -3.364188e-02
# 75%   -6.122879e-03 -5.103303e-02 -1.590614e-02 -7.793980e-03  7.882297e-02
# max    7.631587e+02  5.730332e+02  6.415456e+02  7.002223e+02  5.086535e+02
#
#        ...   r9_taxclass       r1_boro       r2_boro       r3_boro  \
# count  ...  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   ...  2.651688e-14  1.416381e-14 -2.315764e-14  2.107545e-15
# std    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min    ... -1.335327e-01 -3.292877e-01 -2.334633e-01 -1.038394e-01
# 25%    ... -8.399919e-02 -2.007440e-01 -1.567837e-01 -7.387945e-02
# 50%    ... -2.424407e-02 -5.649824e-02 -1.668091e-02 -1.121917e-02
# 75%    ...  1.669894e-02  7.921351e-02  6.022658e-02  2.622304e-02
# max    ...  5.896402e+02  4.618636e+02  4.675608e+02  8.334646e+02
#
#             r4_boro       r5_boro       r6_boro       r7_boro       r8_boro  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean  -2.663685e-16  3.334107e-15  2.559602e-15 -2.050327e-14 -1.902262e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.659210e-02 -3.246591e-02 -2.771338e-02 -8.661033e-02 -4.259928e-02
# 25%   -3.626873e-02 -2.546635e-02 -2.403808e-02 -6.636767e-02 -2.781447e-02
# 50%   -1.771892e-02 -1.221901e-02 -1.282995e-02 -4.368292e-02 -1.636408e-02
# 75%   -3.647703e-04 -4.708114e-03 -6.187080e-03 -1.811434e-02 -7.297386e-03
# max    9.388877e+02  5.531192e+02  6.241236e+02  7.261511e+02  7.526293e+02
#
#             r9_boro
# count  1.070994e+06
# mean  -1.139079e-15
# std    1.000000e+00
# min   -3.929067e-02
# 25%   -2.708941e-02
# 50%   -1.654421e-02
# 75%   -7.309352e-03
# max    5.814213e+02
#
# [8 rows x 45 columns]

# %%
pca = PCA(n_components = .99, svd_solver = 'full')
pca.fit(data_zs)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
plt.yticks(np.arange(0.05, 1.1, step=.1))
plt.xticks(np.arange(0, 20, step=2))
plt.axvline(x=6, linestyle='--')
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
pca = PCA(n_components = 7)
# pca = PCA(n_components = .85, svd_solver = 'full')
princ_comps = pca.fit_transform(data_zs)
pca.n_components_
# Out:
# 7

# %%
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# [0.53169854 0.78121611 0.84502019 0.8854793  0.91587336 0.9373666
#  0.95148805]

# %%
data_pca = pd.DataFrame(princ_comps, columns = ['PC' + str(i) for i in range(1, pca.n_components_+1)])
data_pca.shape
# Out:
# (1070994, 7)

# %%
data_pca.head()
# Out:
#           PC1         PC2        PC3        PC4        PC5        PC6  \
# 0    2.652116   -1.212644   0.301914   1.489034  -1.197227  -0.619431
# 1   68.630832  122.008093 -49.690695  32.808307  51.850714 -13.900873
# 2   -0.085789    0.304139   0.155629  -0.173786  -0.026961   0.054279
# 3    0.661719   -0.618777   0.089461  -0.136348  -0.262801   0.039222
# 4  128.292374  -51.798980 -43.596901 -17.493618  -2.555413   6.122337
#
#          PC7
# 0   0.871586
# 1  33.088031
# 2  -0.115523
# 3   0.025027
# 4   3.979763

# %%
data_pca.describe()
# Out:
#                 PC1           PC2           PC3           PC4           PC5  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# m
# 10   0.222581   0.425628  -0.101006   0.766876   0.190034  -0.454613
# 11  -0.108935  -0.084844   0.207993  -0.134996  -0.100365   0.067843
# 12  -0.059400  -0.007818   0.171411  -0.011809  -0.074023  -0.004512
# 13  -0.064198  -0.015278   0.174954  -0.023740  -0.076574   0.002495
# 14   0.145879   0.311387   0.019810   0.498695   0.035142  -0.304364
# 15   0.138069   0.299243   0.025577   0.479274   0.030989  -0.292956
# 16   0.138069   0.299243   0.025577   0.479274   0.030989  -0.292956
# 17   0.138069   0.299243   0.025577   0.479274   0.030989  -0.292956
# 18   0.138069   0.299243   0.025577   0.479274   0.030989  -0.292956
# 19   0.138069   0.299243   0.025577   0.479274   0.030989  -0.292956
#
#           PC7
# 0    1.093363
# 1   41.507350
# 2   -0.144918
# 3    0.031396
# 4    4.992422
# 5    0.157170
# 6    2.511404
# 7    0.484568
# 8    0.194484
# 9    0.331745
# 10   0.918816
# 11  -0.034744
# 12   0.067339
# 13   0.057453
# 14   0.490389
# 15   0.474294
# 16   0.474294
# 17   0.474294
# 18   0.474294
# 19   0.474294

# %%
p=4
oop = 1/p
score1 = (((data_pca_zs).abs()**p).sum(axis=1))**oop
score1.head(10)
# Out:
# 0     1.437696
# 1    55.890002
# 2     0.171492
# 3     0.254012
# 4    31.614337
# 5     0.621613
# 6    16.350268
# 7     0.993337
# 8     0.217238
# 9     0.392727
# dtype: float64

# %%
score1.max()
# Out:
# 695.0653302248486

# %%
plt.hist(score1, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2141984.4509681487)

# %%
from keras.models import Model
from keras.layers import Input, Dense
# placeholder for input
data_in = Input(shape=(7,))
# dimension of the encoded data. Choose 3
encoded_dim = 3
# encoded representation of the data
encoded = Dense(encoded_dim, activation='tanh')(data_in)
# reconstruction of the input
decoded = Dense(7,activation='tanh')(encoded)
# this model maps the input data to the reconstructed data
autoencoder = Model(data_in, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
# %%time
autoencoder.fit(data_pca_zs,data_pca_zs, epochs=5, shuffle=True, validation_data=(data_pca_zs,data_pca_zs))
# Out:
# Epoch 1/5
# 33469/33469 [==============================] - 27s 799us/step - loss: 1.0893 - val_loss: 0.9268
# Epoch 2/5
# 33469/33469 [==============================] - 27s 794us/step - loss: 1.0565 - val_loss: 0.9253
# Epoch 3/5
# 33469/33469 [==============================] - 26s 786us/step - loss: 1.0097 - val_loss: 0.9247
# Epoch 4/5
# 33469/33469 [==============================] - 27s 794us/step - loss: 0.8622 - val_loss: 0.9245
# Epoch 5/5
# 33469/33469 [==============================] - 26s 789us/step - loss: 0.6298 - val_loss: 0.9244
# CPU times: user 3min 5s, sys: 27.4 s, total: 3min 32s
# Wall time: 2min 12s

# %%
# %%time
pca_out = autoencoder.predict(data_pca_zs)
error = pca_out - data_pca_zs
p=1
oop=1/p
# score2 =np.power(np.sum(np.power(error, p), axis=1),oop)
score2 = ((error.abs()**p).sum(axis=1))**oop
# Out:
# CPU times: user 10.8 s, sys: 1.79 s, total: 12.5 s
# Wall time: 8.41 s

# %%
score2.head(10)
# Out:
# 0      2.464711
# 1    197.065552
# 2      0.371555
# 3      0.656299
# 4     94.786377
# 5      1.364360
# 6     50.175523
# 7      1.875230
# 8      0.455236
# 9      0.668867
# dtype: float64

# %%
scores = pd.DataFrame(score1)
scores.columns=['score1']
scores['score2'] = score2
scores.head()
# Out:
#       score1      score2
# 0   1.437696    2.464711
# 1  55.890002  197.065552
# 2   0.171492    0.371555
# 3   0.254012    0.656299
# 4  31.614337   94.786377

# %%
scores['score1 rank'] = scores['score1'].rank()
scores['score2 rank'] = scores['score2'].rank()
scores.head(10)
# Out:
#       score1      score2  score1 rank  score2 rank
# 0   1.437696    2.464711    1047866.0    1053577.0
# 1  55.890002  197.065552    1070889.0    1070903.0
# 2   0.171492    0.371555     475931.0     910957.0
# 3   0.254012    0.656299     663884.0    1005141.0
# 4  31.614337   94.786377    1070763.0    1070770.0
# 5   0.621613    1.364360    1012903.0    1041803.0
# 6  16.350268   50.175523    1070402.0    1070475.0
# 7   0.993337    1.875230    1037831.0    1049059.0
# 8   0.217238    0.455236     593054.0     957962.0
# 9   0.392727    0.668867     956679.0    1006877.0

# %%
scores['final'] = (scores['score1 rank'] + scores['score2 rank'])/2
scores_sorted = scores.sort_values(by='final', ascending=False)
scores_sorted.head(20)
# Out:
#              score1       score2  score1 rank  score2 rank      final
# 917941   695.065330  2205.968617    1070994.0    1070994.0  1070994.0
# 565391   658.528114  2025.782974    1070993.0    1070993.0  1070993.0
# 85885    607.148047  1922.862149    1070992.0    1070992.0  1070992.0
# 684703   449.334767  1273.092214    1070991.0    1070990.0  1070990.5
# 67128    428.724855  1322.901981    1070990.0    1070991.0  1070990.5
# 690832   306.264949   951.861300    1070988.0    1070989.0  1070988.5
# 915468   337.310956   949.355019    1070989.0    1070988.0  1070988.5
# 44247    247.306158   820.766450    1070987.0    1070987.0  1070987.0
# 1059882  236.315364   711.221036    1070986.0    1070985.0  1070985.5
# 116646   225.272245   679.510502    1070985.0    1070984.0  1070984.5
# 501142   196.799620   717.737001    1070979.0    1070986.0  1070982.5
# 39769    224.828736   627.855082    1070984.0    1070981.0  1070982.5
# 565397   209.896507   678.803979    1070982.0    1070983.0  1070982.5
# 556608   200.060714   665.625622    1070981.0    1070982.0  1070981.5
# 106680   186.249986   538.836886    1070977.0    1070978.0  1070977.5
# 957063   166.222771   619.707907    1070973.0    1070980.0  1070976.5
# 151043   174.024399   518.228749    1070975.0    1070977.0  1070976.0
# 738017   189.848460   494.928575    1070978.0    1070974.0  1070976.0
# 33750    196.801472   476.650541    1070980.0    1070971.0  1070975.5
# 1065869  179.198751   507.279994    1070976.0    1070975.0  1070975.5

# %%
scores_sorted.tail(10)
# Out:
#            score1    score2  score1 rank  score2 rank  final
# 863713   0.026526  0.021169       1238.0        490.0  864.0
# 740389   0.019992  0.026015        142.0       1520.0  831.0
# 819139   0.025053  0.022405        903.0        698.0  800.5
# 809113   0.021115  0.025406        244.5       1343.5  794.0
# 809112   0.021115  0.025406        244.5       1343.5  794.0
# 860306   0.022650  0.023846        469.0        957.0  713.0
# 1037520  0.024754  0.020878        826.0        423.0  624.5
# 860322   0.018027  0.024717         61.5       1127.5  594.5
# 860324   0.018027  0.024717         61.5       1127.5  594.5
# 860323   0.017275  0.024201         38.0       1028.0  533.0

# %%
plt.hist(score1, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2141984.4509681487)

# %%
plt.hist(score2, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2135945.4765775013)

# %%
sns.distplot(scores['final'])
# Out:
# /Users/haotian/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
top_records = scores.sort_values(['final'], ascending = False).head(200).index
print(top_records)
# Out:
# Int64Index([ 917941,  565391,   85885,  684703,   67128,  690832,  915468,
#               44247, 1059882,  116646,
#             ...
#              253499,  106726,   89346,  293329,  921815,  972960,  987665,
#               56119,  917944,  926191],
#            dtype='int64', length=200)

# %%
data_zs_top_n = data_zs.iloc[top_records]
data_zs_top_n.transpose()
# Out:
#                 917941      565391      85885       684703      67128    \
# r1             0.535636  512.765210   -0.141711  209.994955   81.640121
# r2            28.155462  328.137810  471.007306   -0.159183  466.558209
# r3            14.607118   93.955048  735.572763   -0.138220  133.630975
# r4            15.196011  861.816504    0.231539   20.610045  132.685538
# r5           323.460897  351.253292  501.836908   -0.024656  481.468505
# r6           163.953849   98.049397  763.158673   -0.019945  134.402892
# r7            26.318384  573.033245    0.094670   13.647789   91.448412
# r8           641.545643  267.519796  383.932975   -0.040397  380.307754
# r9           389.987533   89.549858  700.222268   -0.031106  127.312210
# r1_zip5        1.492310  508.653468   -0.165887  224.806257   33.568954
# r2_zip5       31.186815  251.721405  544.809022   -0.158736  232.877864
# r3_zip5       12.699132   64.402916  697.801722   -0.130036  133.721190
# r4_zip5       44.144761  727.995459    0.113772   45.910629   42.029163
# r5_zip5      289.767564  328.625863  285.587099   -0.053166  143.941543
# r6_zip5      213.137580  175.466821  303.771786   -0.048979  119.109470
# r7_zip5       88.893844  641.569639   -0.008354   25.826514   20.673876
# r8_zip5      431.769328  338.574420  269.176365   -0.072954  127.588515
# r9_zip5      333.009774  162.536405  373.471753   -0.066196  113.154315
# r1_zip3        1.024486  460.338575   -0.222939  240.711366   48.872642
# r2_zip3       27.583387  302.100136  452.016094   -0.165930  447.746314
# r3_zip3        8.410477   55.959847  827.381618   -0.091679  150.376636
# r4_zip3       24.827714  937.628638    0.022802   24.135909   31.338177
# r5_zip3      411.564576  555.917918  246.005971   -0.027314  236.020414
# r6_zip3      233.842249  180.650105  609.339238   -0.026524  107.303924
# r7_zip3       63.644980  724.493768   -0.038610   20.731598   22.261560
# r8_zip3      784.982794  341.100075  136.903897   -0.037121  135.610966
# r9_zip3      504.023203  134.124517  554.388074   -0.037511  100.786189
# r3_zip3       7.657129   0.895339   0.111715   2.066734
# r4_zip3       0.009015   3.954036  38.005836   0.707297
# r5_zip3      24.849993   3.332258   1.762722   0.742999
# r6_zip3      18.819331   0.174747   0.533332   0.289288
# r7_zip3      -0.039247   9.925150  37.355627   0.769603
# r8_zip3      19.567407   6.754934   1.274046   0.670905
# r9_zip3      16.498923   0.631833   0.425824   0.281407
# r1_taxclass  -0.252455  26.010235   9.667887   7.963364
# r2_taxclass  12.762063  18.673879   0.880862  24.295296
# r3_taxclass  11.422721   0.672049   0.198824  19.987377
# r4_taxclass  -0.144251  12.167267  16.858047  11.143688
# r5_taxclass  13.827140   5.463670   1.032426  24.375045
# r6_taxclass  11.319116   0.118537   0.240590  22.267387
# r7_taxclass  -0.239116  24.451607   9.087439  15.196301
# r8_taxclass   9.847912  14.411906   0.675479  31.046119
# r9_taxclass   9.912371   0.580312   0.169532  28.471116
# r1_boro      -0.268982  22.352870  17.798320   4.605042
# r2_boro      18.414797  22.980921   1.014683   9.128712
# r3_boro       7.484971   0.905088   0.096135   1.938746
# r4_boro       0.009027   4.109010  30.163306   0.722871
# r5_boro      24.721420   3.445000   1.624566   1.130569
# r6_boro      18.288018   0.180483   0.440697   0.419982
# r7_boro      -0.039330  10.263942  26.635713   0.594022
# r8_boro      20.338759   7.260827   1.218236   0.842354
# r9_boro      16.524523   0.664492   0.370580   0.352455
#
# [45 rows x 200 columns]

# %%
NY_data_orig.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  ...  BLDFRONT BLDDEPTH      AVLAND2       AVTOT2  \
# 0        4      500  ...         0        0    3775500.0    8613000.0
# 1        4       27  ...         0        0   11111400.0   80690400.0
# 2        4      709  ...       709      564   32321790.0   40179510.0
# 3        4      793  ...        85      551   13644000.0   15750000.0
# 4        4      323  ...        89       57  106348680.0  107758350.0
#
#        EXLAND2       EXTOT2  EXCD2  PERIOD     YEAR VALTYPE
# 0    3775500.0    8613000.0    NaN   FINAL  2010/11   AC-TR
# 1   11111400.0   80690400.0    NaN   FINAL  2010/11   AC-TR
# 2   32321790.0   40179510.0    NaN   FINAL  2010/11   AC-TR
# 3   13644000.0   15750000.0    NaN   FINAL  2010/11   AC-TR
# 4  106348680.0  107758350.0    NaN   FINAL  2010/11   AC-TR
#
# [5 rows x 32 columns]

# %%
scores.head()
# Out:
#       score1      score2  score1 rank  score2 rank      final
# 0   1.437696    2.464711    1047866.0    1053577.0  1050721.5
# 1  55.890002  197.065552    1070889.0    1070903.0  1070896.0
# 2   0.171492    0.371555     475931.0     910957.0   693444.0
# 3   0.254012    0.656299     663884.0    1005141.0   834512.5
# 4  31.614337   94.786377    1070763.0    1070770.0  1070766.5

# %%
NY_data_with_scores = NY_data_orig.join(scores)
NY_data_with_scores.set_index('RECORD',inplace=True)
NY_data_with_scores.head()
# Out:
#               BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 1       1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 2       1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 3       1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 4       1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 5       1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...       EXTOT2  EXCD2  PERIOD     YEAR  \
# RECORD                             ...
# 1             4      500     1046  ...    8613000.0    NaN   FINAL  2010/11
# 2             4       27        0  ...   80690400.0    NaN   FINAL  2010/11
# 3             4      709      564  ...   40179510.0    NaN   FINAL  2010/11
# 4             4      793      551  ...   15750000.0    NaN   FINAL  2010/11
# 5             4      323     1260  ...  107758350.0    NaN   FINAL  2010/11
#
#         VALTYPE     score1      score2  score1 rank score2 rank      final
# RECORD
# 1         AC-TR   1.437696    2.464711    1047866.0   1053577.0  1050721.5
# 2         AC-TR  55.890002  197.065552    1070889.0   1070903.0  1070896.0
# 3         AC-TR   0.171492    0.371555     475931.0    910957.0   693444.0
# 4         AC-TR   0.254012    0.656299     663884.0   1005141.0   834512.5
# 5         AC-TR  31.614337   94.786377    1070763.0   1070770.0  1070766.5
#
# [5 rows x 36 columns]

# %%
NY_data_top_n = NY_data_with_scores.sort_values(['final'], ascending = False).head(200)
NY_data_top_n
# Out:
#                BBLE  B  BLOCK   LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 917942   4142600001  4  14260     1      NaN   LOGAN PROPERTY, INC.     T1
# 565392   3085900700  3   8590   700      NaN   U S GOVERNMENT OWNRD     V9
# 85886    1012540010  1   1254    10      NaN   PARKS AND RECREATION     Q1
# 684704   4036590105  4   3659   105      NaN               W RUFERT     V0
# 67129    1011110001  1   1111     1      NaN       CULTURAL AFFAIRS     Q1
# ...             ... ..    ...   ...      ...                    ...    ...
# 972961  5012610063E  5   1261    63        E                    NaN     Z7
# 987666   5023900194  5   2390   194      NaN  SI HISTORICAL SOCIETY     P9
# 56120    1009941001  1    994  1001      NaN  BLACKHAWK ACQUISITION     R5
# 917945   4142600060  4  14260    60      NaN                    NaN     V1
# 926192   4159050001  4  15905     1      NaN  BENJAMIN BEECHWOOD DU     V0
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...        EXTOT2  EXCD2  PERIOD     YEAR  \
# RECORD                             ...
# 917942        4     4910        0  ...  4.501180e+09    NaN   FINAL  2010/11
# 565392        4      117      108  ...  8.484847e+08    NaN   FINAL  2010/11
# 85886         4     4000      150  ...  2.826018e+07    NaN   FINAL  2010/11
# 684704       1B        2        2  ...           NaN    NaN   FINAL  2010/11
# 67129         4      840        0  ...  2.465055e+09    NaN   FINAL  2010/11
# ...         ...      ...      ...  ...           ...    ...     ...      ...
# 972961        4       14       10  ...           NaN    NaN   FINAL  2010/11
# 987666        4      640      775  ...  5.622264e+06    NaN   FINAL  2010/11
# 56120         4        0        0  ...  5.938832e+07    NaN   FINAL  2010/11
# 917945        4       14        0  ...           NaN    NaN   FINAL  2010/11
# 926192       1B      200      149  ...           NaN    NaN   FINAL  2010/11
#
#         VALTYPE      score1       score2  score1 rank score2 rank      final
# RECORD
# 917942    AC-TR  695.065330  2205.968617    1070994.0   1070994.0  1070994.0
# 565392    AC-TR  658.528114  2025.782974    1070993.0   1070993.0  1070993.0
# 85886     AC-TR  607.148047  1922.862149    1070992.0   1070992.0  1070992.0
# 684704    AC-TR  449.334767  1273.092214    1070991.0   1070990.0  1070990.5
# 67129     AC-TR  428.724855  1322.901981    1070990.0   1070991.0  1070990.5
# ...         ...         ...          ...          ...         ...        ...
# 972961    AC-TR   36.077233   101.934336    1070805.0   1070793.0  1070799.0
# 987666    AC-TR   34.758266   107.866407    1070785.0   1070807.0  1070796.0
# 56120     AC-TR   33.860443   109.428174    1070776.0   1070809.0  1070792.5
# 917945    AC-TR   34.574420   105.860214    1070782.0   1070802.0  1070792.0
# 926192    AC-TR   35.707706    97.424995    1070803.0   1070777.0  1070790.0
#
# [200 rows x 36 columns]

# %%
data_zs_top_n['RECORD'] = (data_zs_top_n.index + 1).astype(int)
data_zs_top_n.set_index('RECORD',inplace=True)
data_zs_top_n
# Out:
# <ipython-input-72-22eaf6cbeac5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_zs_top_n['RECORD'] = (data_zs_top_n.index + 1).astype(int)
#                 r1          r2          r3          r4          r5  \
# RECORD
# 917942    0.535636   28.155462   14.607118   15.196011  323.460897
# 565392  512.765210  328.137810   93.955048  861.816504  351.253292
# 85886    -0.141711  471.007306  735.572763    0.231539  501.836908
# 684704  209.994955   -0.159183   -0.138220   20.610045   -0.024656
# 67129    81.640121  466.558209  133.630975  132.685538  481.468505
# ...            ...         ...         ...         ...         ...
# 972961   34.063828    0.010762   -0.097165   23.950690    0.079155
# 987666   -0.274734   15.820707   12.365173    0.009325   17.125594
# 56120    36.398572   23.152372    0.723476   16.859400    6.834385
# 917945   13.578064    1.085981    0.211029   23.279405    1.381762
# 926192    3.465175    9.660670    3.694674    0.532783    0.961100
#
#                 r6          r7          r8          r9     r1_zip5  ...  \
# RECORD                                                              ...
# 917942  163.953849   26.318384  641.545643  389.987533    1.492310  ...
# 565392   98.049397  573.033245  267.519796   89.549858  508.653468  ...
# 85886   763.158673    0.094670  383.932975  700.222268   -0.165887  ...
# 684704   -0.019945   13.647789   -0.040397   -0.031106  224.806257  ...
# 67129   134.402892   91.448412  380.307754  127.312210   33.568954  ...
# ...            ...         ...         ...         ...         ...  ...
# 972961    0.008570   39.455228    0.160682    0.035790   44.627557  ...
# 987666   13.021876   -0.053923   13.037014   11.895073   -0.304078  ...
# 56120     0.232870   40.911701   19.011014    0.814856   19.401906  ...
# 917945    0.372232   15.420235    1.030838    0.327125   29.693086  ...
# 926192    0.354811    0.294116    0.710430    0.311213    6.381628  ...
#
#         r9_taxclass     r1_boro     r2_boro     r3_boro     r4_boro  \
# RECORD
# 917942   328.352098    0.783165   26.629905    7.710688   19.701153
# 565392    75.315338  461.863588  304.868676   54.703561  938.887683
# 85886    589.640208   -0.220949  467.560770  833.464564    0.025431
# 684704    -0.000002  274.043849   -0.163587   -0.088594   26.708414
# 67129    107.119815   50.302149  463.144208  151.484805   32.554357
# ...             ...         ...         ...         ...         ...
# 972961    -0.075839   48.634271    0.049725   -0.061525   18.749719
# 987666     9.912371   -0.268982   18.414797    7.484971    0.009027
# 56120      0.580312   22.352870   22.980921    0.905088    4.109010
# 917945     0.169532   17.798320    1.014683    0.096135   30.163306
# 926192    28.471116    4.605042    9.128712    1.938746    0.722871
#
#            r5_boro     r6_boro     r7_boro     r8_boro     r9_boro
# RECORD
# 917942  379.852884  194.948448   45.398373  752.629322  444.211540
# 565392  553.119217  175.573719  726.151150  354.612509  134.353747
# 85886   254.237338  624.123556   -0.037172  147.129115  581.421285
# 684704   -0.027038   -0.025624   23.584205   -0.038468   -0.037462
# 67129   243.917715  109.908658   23.018041  145.739630  105.702266
# ...            ...         ...         ...         ...         ...
# 972961    0.124000    0.014795   39.452234    0.276188    0.055836
# 987666   24.721420   18.288018   -0.039330   20.338759   16.524523
# 56120     3.445000    0.180483   10.263942    7.260827    0.664492
# 917945    1.624566    0.440697   26.635713    1.218236    0.370580
# 926192    1.130569    0.419982    0.594022    0.842354    0.352455
#
# [200 rows x 45 columns]

# %%
NY_data_top_n.to_csv('Data/NY_top_2.csv', index=True)
data_zs_top_n.to_csv('Data/data_zs_top_2.csv', index=True)

# %%
data_zs_top_n_abs = data_zs_top_n.abs()
data_heatmap = data_zs_top_n.abs().head(10)
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap_2.png')

# %%
print('Duration: ', datetime.now() - start_time)
# Out:
# Duration:  0:07:04.858734

# %% [markdown]
# ## Compare the two models

# %%
NY_data_1 = pd.read_csv('Data/NY_top.csv',index_col='RECORD')
NY_data_2 = NY_data_top_n.copy()

# %%
NY_data_1.head(10)
# Out:
#               BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 917942  4142600001  4  14260    1      NaN   LOGAN PROPERTY, INC.     T1
# 565392  3085900700  3   8590  700      NaN   U S GOVERNMENT OWNRD     V9
# 85886   1012540010  1   1254   10      NaN   PARKS AND RECREATION     Q1
# 67129   1011110001  1   1111    1      NaN       CULTURAL AFFAIRS     Q1
# 684704  4036590105  4   3659  105      NaN               W RUFERT     V0
# 690833  4038660070  4   3866   70      NaN   PARKS AND RECREATION     Q1
# 915469  4141400001  4  14140    1      NaN  UNITED STATES OF AMER     V0
# 44248   1008520001  1    852    1      NaN   PARKS AND RECREATION     Q1
# 565398  3085910100  3   8591  100      NaN  DEPT OF GENERAL SERVI     V9
# 39770   1007980066  1    798   66      NaN  GREENHORN DEVELOPMENT     D9
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...        EXTOT2  EXCD2  PERIOD     YEAR  \
# RECORD                             ...
# 917942        4     4910        0  ...  4.501180e+09    NaN   FINAL  2010/11
# 565392        4      117      108  ...  8.484847e+08    NaN   FINAL  2010/11
# 85886         4     4000      150  ...  2.826018e+07    NaN   FINAL  2010/11
# 67129         4      840        0  ...  2.465055e+09    NaN   FINAL  2010/11
# 684704       1B        2        2  ...           NaN    NaN   FINAL  2010/11
# 690833        4      610      534  ...  1.024200e+08    NaN   FINAL  2010/11
# 915469       1B      999      999  ...           NaN    NaN   FINAL  2010/11
# 44248         4      420      740  ...  7.490385e+07    NaN   FINAL  2010/11
# 565398        4      466     1009  ...  4.352642e+08    NaN   FINAL  2010/11
# 39770         2       75       98  ...           NaN    NaN   FINAL  2010/11
#
#         VALTYPE      score1      score2  score1 rank score2 rank      final
# RECORD
# 917942    AC-TR  918.967159  918.536178    1070994.0   1070994.0  1070994.0
# 565392    AC-TR  871.086517  870.622083    1070993.0   1070993.0  1070993.0
# 85886     AC-TR  812.139512  810.871173    1070992.0   1070992.0  1070992.0
# 67129     AC-TR  553.564546  551.662993    1070991.0   1070991.0  1070991.0
# 684704    AC-TR  545.849402  543.818952    1070990.0   1070990.0  1070990.0
# 690833    AC-TR  421.543323  420.383577    1070989.0   1070989.0  1070989.0
# 915469    AC-TR  407.276982  405.446832    1070988.0   1070988.0  1070988.0
# 44248     AC-TR  334.787210  333.617400    1070987.0   1070987.0  1070987.0
# 565398    AC-TR  295.813907  294.807826    1070986.0   1070986.0  1070986.0
# 39770     AC-TR  281.505843  279.689267    1070985.0   1070985.0  1070985.0
#
# [10 rows x 36 columns]

# %%
NY_data_2.head(10)
# Out:
#                 BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 917942    4142600001  4  14260    1      NaN   LOGAN PROPERTY, INC.     T1
# 565392    3085900700  3   8590  700      NaN   U S GOVERNMENT OWNRD     V9
# 85886     1012540010  1   1254   10      NaN   PARKS AND RECREATION     Q1
# 684704    4036590105  4   3659  105      NaN               W RUFERT     V0
# 67129     1011110001  1   1111    1      NaN       CULTURAL AFFAIRS     Q1
# 690833    4038660070  4   3866   70      NaN   PARKS AND RECREATION     Q1
# 915469    4141400001  4  14140    1      NaN  UNITED STATES OF AMER     V0
# 44248     1008520001  1    852    1      NaN   PARKS AND RECREATION     Q1
# 1059883  5069770012E  5   6977   12        E                    NaN     Z7
# 116647    1015410021  1   1541   21      NaN   MF ASSOCIATES OF NEW     D6
#
#         TAXCLASS  LTFRONT  LTDEPTH  ...        EXTOT2  EXCD2  PERIOD     YEAR  \
# RECORD                              ...
# 917942         4     4910        0  ...  4.501180e+09    NaN   FINAL  2010/11
# 565392         4      117      108  ...  8.484847e+08    NaN   FINAL  2010/11
# 85886          4     4000      150  ...  2.826018e+07    NaN   FINAL  2010/11
# 684704        1B        2        2  ...           NaN    NaN   FINAL  2010/11
# 67129          4      840        0  ...  2.465055e+09    NaN   FINAL  2010/11
# 690833         4      610      534  ...  1.024200e+08    NaN   FINAL  2010/11
# 915469        1B      999      999  ...           NaN    NaN   FINAL  2010/11
# 44248          4      420      740  ...  7.490385e+07    NaN   FINAL  2010/11
# 1059883        4        5        5  ...           NaN    NaN   FINAL  2010/11
# 116647         2       25       75  ...           NaN    NaN   FINAL  2010/11
#
#          VALTYPE      score1       score2  score1 rank score2 rank      final
# RECORD
# 917942     AC-TR  695.065330  2205.968617    1070994.0   1070994.0  1070994.0
# 565392     AC-TR  658.528114  2025.782974    1070993.0   1070993.0  1070993.0
# 85886      AC-TR  607.148047  1922.862149    1070992.0   1070992.0  1070992.0
# 684704     AC-TR  449.334767  1273.092214    1070991.0   1070990.0  1070990.5
# 67129      AC-TR  428.724855  1322.901981    1070990.0   1070991.0  1070990.5
# 690833     AC-TR  306.264949   951.861300    1070988.0   1070989.0  1070988.5
# 915469     AC-TR  337.310956   949.355019    1070989.0   1070988.0  1070988.5
# 44248      AC-TR  247.306158   820.766450    1070987.0   1070987.0  1070987.0
# 1059883    AC-TR  236.315364   711.221036    1070986.0   1070985.0  1070985.5
# 116647     AC-TR  225.272245   679.510502    1070985.0   1070984.0  1070984.5
#
# [10 rows x 36 columns]

# %%
# compare the two
top1 = NY_data_1[:100]
top2 = NY_data_2[:100]

list1 = top1.index
list2 = top2.index

overlap = list1 & list2

def Diff(list1, list2):
    list_diff = [i for i in list2 if i not in list1]
    return list_diff
dif = Diff(list1,list2)
percent = (len(dif)/100)*100
print(percent)
# Out:
# 5.0

# %%
pd.set_option('display.max_columns', None)
NY_data_2.head(10)
# Out:
#                 BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 917942    4142600001  4  14260    1      NaN   LOGAN PROPERTY, INC.     T1
# 565392    3085900700  3   8590  700      NaN   U S GOVERNMENT OWNRD     V9
# 85886     1012540010  1   1254   10      NaN   PARKS AND RECREATION     Q1
# 684704    4036590105  4   3659  105      NaN               W RUFERT     V0
# 67129     1011110001  1   1111    1      NaN       CULTURAL AFFAIRS     Q1
# 690833    4038660070  4   3866   70      NaN   PARKS AND RECREATION     Q1
# 915469    4141400001  4  14140    1      NaN  UNITED STATES OF AMER     V0
# 44248     1008520001  1    852    1      NaN   PARKS AND RECREATION     Q1
# 1059883  5069770012E  5   6977   12        E                    NaN     Z7
# 116647    1015410021  1   1541   21      NaN   MF ASSOCIATES OF NEW     D6
#
#         TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES       FULLVAL        AVLAND  \
# RECORD
# 917942         4     4910        0  NaN      3.0  3.740199e+08  1.792809e+09
# 565392         4      117      108  NaN      NaN  4.326304e+09  1.946837e+09
# 85886          4     4000      150  NaN      1.0  7.021400e+07  3.145500e+07
# 684704        1B        2        2  NaN      NaN  0.000000e+00  0.000000e+00
# 67129          4      840        0    E      NaN  6.150000e+09  2.668500e+09
# 690833         4      610      534  NaN      3.0  2.420000e+08  1.035000e+08
# 915469        1B      999      999  NaN      NaN  5.401435e+08  3.240861e+07
# 44248          4      420      740  NaN      1.0  1.796250e+08  7.695000e+07
# 1059883        4        5        5  NaN      NaN  0.000000e+00  0.000000e+00
# 116647         2       25       75  NaN     35.0  1.610000e+08  1.921500e+07
#
#                 AVTOT        EXLAND         EXTOT   EXCD1  \
# RECORD
# 917942   4.668309e+09  1.792809e+09  4.668309e+09  2198.0
# 565392   1.946837e+09  1.946837e+09  1.946837e+09  2231.0
# 85886    3.159630e+07  3.145500e+07  3.159630e+07  2231.0
# 684704   0.000000e+00  0.000000e+00  0.000000e+00     NaN
# 67129    2.767500e+09  2.668500e+09  2.767500e+09  2231.0
# 690833   1.089000e+08  1.035000e+08  1.089000e+08  2231.0
# 915469   3.240861e+07  3.240861e+07  3.240861e+07  4600.0
# 44248    8.083125e+07  7.695000e+07  8.083125e+07  2231.0
# 1059883  0.000000e+00  0.000000e+00  0.000000e+00     NaN
# 116647   7.245000e+07  0.000000e+00  0.000000e+00     NaN
#
#                               STADDR      ZIP EXMPTCL  BLDFRONT  BLDDEPTH  \
# RECORD
# 917942   154-68 BROOKVILLE BOULEVARD  11422.0      X4         0         0
# 565392               FLATBUSH AVENUE      NaN      X1         0         0
# 85886           JOE DIMAGGIO HIGHWAY      NaN      X1         8         8
# 684704                     69 STREET      NaN     NaN         0         0
# 67129                  1000 5 AVENUE  10028.0      X1         0         0
# 690833          83-98 FOREST PARKWAY  11385.0      X1        20        20
# 915469           CROSS BAY BOULEVARD  11414.0      X3         0         0
# 44248               2 MADISON AVENUE  10010.0      X1        20        20
# 1059883                 SAGONA COURT      NaN     NaN         0         0
# 116647                 1849 2 AVENUE  10128.0     NaN        70       456
#
#               AVLAND2        AVTOT2       EXLAND2        EXTOT2  EXCD2 PERIOD  \
# RECORD
# 917942   1.644454e+09  4.501180e+09  1.644454e+09  4.501180e+09    NaN  FINAL
# 565392   8.484847e+08  8.484847e+08  8.484847e+08  8.484847e+08    NaN  FINAL
# 85886    2.813400e+07  2.826018e+07  2.813400e+07  2.826018e+07    NaN  FINAL
# 684704            NaN           NaN           NaN           NaN    NaN  FINAL
# 67129    2.371005e+09  2.465055e+09  2.371005e+09  2.465055e+09    NaN  FINAL
# 690833   9.702000e+07  1.024200e+08  9.702000e+07  1.024200e+08    NaN  FINAL
# 915469            NaN           NaN           NaN           NaN    NaN  FINAL
# 44248    7.115760e+07  7.490385e+07  7.115760e+07  7.490385e+07    NaN  FINAL
# 1059883           NaN           NaN           NaN           NaN    NaN  FINAL
# 116647   1.921500e+07  6.696000e+07           NaN           NaN    NaN  FINAL
#
#             YEAR VALTYPE      score1       score2  score1 rank  score2 rank  \
# RECORD
# 917942   2010/11   AC-TR  695.065330  2205.968617    1070994.0    1070994.0
# 565392   2010/11   AC-TR  658.528114  2025.782974    1070993.0    1070993.0
# 85886    2010/11   AC-TR  607.148047  1922.862149    1070992.0    1070992.0
# 684704   2010/11   AC-TR  449.334767  1273.092214    1070991.0    1070990.0
# 67129    2010/11   AC-TR  428.724855  1322.901981    1070990.0    1070991.0
# 690833   2010/11   AC-TR  306.264949   951.861300    1070988.0    1070989.0
# 915469   2010/11   AC-TR  337.310956   949.355019    1070989.0    1070988.0
# 44248    2010/11   AC-TR  247.306158   820.766450    1070987.0    1070987.0
# 1059883  2010/11   AC-TR  236.315364   711.221036    1070986.0    1070985.0
# 116647   2010/11   AC-TR  225.272245   679.510502    1070985.0    1070984.0
#
#              final
# RECORD
# 917942   1070994.0
# 565392   1070993.0
# 85886    1070992.0
# 684704   1070990.5
# 67129    1070990.5
# 690833   1070988.5
# 915469   1070988.5
# 44248    1070987.0
# 1059883  1070985.5
# 116647   1070984.5

# %%
top1.shape
# Out:
# (100, 36)

# %%
top2.shape
# Out:
# (100, 36)

# %%
top1.to_csv('Data/top_100_part_1.csv', index=True)
top2.to_csv('Data/top_100_part_2.csv', index=True)
